# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import DirectoryLoader

pdf_loader = DirectoryLoader("data/pdf/", glob="**/*.pdf", loader_cls=PyMuPDFLoader)
pdf_loader.load()
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\AI_RAG.pdf', 'file_path': 'data\\pdf\\AI_RAG.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='AI & RAG\nUnistack Solutions develops Retrieval-Augmented Generation (RAG) systems using LangChain,\nLangGraph, OpenAI-compatible models, embeddings and vector databases such as ChromaDB,\nQdrant, FAISS and Pinecone.\nTypical workflow: Load Documents → Chunk Text → Create Embeddings → Store in Vector DB →\nSimilarity Search → Generate LLM Response.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\Company_Overview.pdf', 'file_path': 'data\\pdf\\Company_Overview.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='Unistack Solutions\nUnistack Solutions is a software development\ncompany specializing in AI, Machine Learning,\nWeb Development, Mobile Apps, Cloud Computing,\nDevOps, Business Automation, ERP, CRM, and\nenterprise digital transformation.\nMission: Deliver scalable, secure and innovative\nsoftware solutions.\nVision: Become a trusted global technology\npartner.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\Contact.pdf', 'file_path': 'data\\pdf\\Contact.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='Contact\nCompany: Unistack Solutions\nWebsite: https://www.unistacksolutions.com\nEmail: info@unistacksolutions.com\nBusiness Hours: Monday-Friday, 9:00 AM - 6:00 PM IST'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\FAQ.pdf', 'file_path': 'data\\pdf\\FAQ.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='Frequently Asked Questions\nQ: What services do you provide?\nA: AI, Web, Mobile, Cloud, DevOps and Business Automation.\nQ: Which technologies do you use?\nA: Python, Django, FastAPI, React, Angular, Node.js, Docker and Kubernetes.\nQ: Do you build AI chatbots?\nA: Yes, including RAG-based document assistants.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\Services.pdf', 'file_path': 'data\\pdf\\Services.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='Services\n• Artificial Intelligence\n• Generative AI\n• RAG Applications\n• AI Chatbots\n• OCR Solutions\n• Computer Vision\n• Web Development (React, Angular, Next.js, Django, FastAPI)\n• Mobile Development (Flutter, React Native)\n• Cloud & DevOps\n• Business Automation'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-25T10:10:43+00:00', 'source': 'data\\pdf\\Technologies.pdf', 'file_path': 'data\\pdf\\Technologies.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-25T10:10:43+00:00', 'trapped': '', 'modDate': "D:20260625101043+00'00'", 'creationDate': "D:20260625101043+00'00'", 'page': 0}, page_content='Technologies\nFrontend: React, Next.js, Angular, Vue, HTML, CSS, Tailwind.\nBackend: Python, Django, FastAPI, Node.js, Express.\nDatabases: PostgreSQL, MongoDB, MySQL, Redis, SQLite.\nCloud: AWS, Azure, Google Cloud.\nDevOps: Docker, Kubernetes, GitHub Actions, Jenkins, Terraform.')]
